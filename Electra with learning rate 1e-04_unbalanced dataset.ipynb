# %%
import pandas as pd
import numpy as np
import nltk
import tensorflow as tf
import transformers #huggingface transformers library
from transformers import pipeline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import sklearn
from sklearn.metrics import confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt
from transformers import (ElectraForSequenceClassification,TFElectraModel,
                          ElectraTokenizerFast, EvalPrediction, InputFeatures,
                          Trainer, TrainingArguments, glue_compute_metrics)
from typing import List

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
# Detect hardware, return appropriate distribution strategy
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is
    # set: this is always the case on Kaggle.
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# REPLICAS:  1

# %%
df = pd.read_csv("data_transformer.csv")

# %%
df.head()
# Out:
#                                           text_clean  target
# 0  from a gender perspective paulgaard points out...       5
# 1  the average figure also masks large difference...       3
# 2  the israel oceanographic and limnological rese...       6
# 3  previous chapters have discussed ways to make ...       2
# 4  prescription rates appear to be higher where l...       8

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='target',data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
#since I am using bert-large-uncased as the model, I am converting each of the news headlines and descriptions into lower case.
df['text_clean'] = df['text_clean'].apply(lambda news: str(news).lower())

# %%
#calculating the length of headlines and descriptions
df['text_clean_len'] = df['text_clean'].apply(lambda x: len(str(x).split()))

# %%
df.describe()
# Out:
#              target  text_clean_len
# count  17631.000000    17631.000000
# mean       6.677103       89.446827
# std        3.890232       28.881372
# min        1.000000       23.000000
# 25%        4.000000       68.000000
# 50%        6.000000       84.000000
# 75%        9.000000      106.000000
# max       15.000000      226.000000

# %%
sns.displot(df['text_clean_len'])
plt.title('Description Number of Words in News')
plt.show()

# %%
from __future__ import print_function
import ipywidgets as widgets
import re

# %%
def clean_text(text):
    text = text.encode("ascii", errors="ignore").decode("ascii") #remove non-ascii, Chinese characters
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"\n", " ", text)
    text = re.sub(r"\n\n", " ", text)
    text = re.sub(r"\W", " ", text)
    text = re.sub(r"^\d+\s|\s\d+\s|\s\d+$", " ", text)
    text = text.strip(" ")
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(' +',' ', text).strip() # get rid of multiple spaces and replace with a single
    return text

# %%
df["text_clean"] = df["text_clean"].apply(clean_text)

# %%
def regular_encode(texts, tokenizer, maxlen=512):
    enc_di = tokenizer.batch_encode_plus(
        texts,         
        return_token_type_ids=False,
        padding='max_length',
        max_length=maxlen, 
        truncation=True
    )
    
    return np.array(enc_di['input_ids'])

# %%
model = ElectraForSequenceClassification.from_pretrained(
    "google/electra-small-discriminator", num_labels = 16)

tokenizer = ElectraTokenizerFast.from_pretrained(
    "google/electra-small-discriminator", do_lower_case=True)
# Out:
# Some weights of the model checkpoint at google/electra-small-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at google/electra-small-discriminator and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
X_train,X_test ,y_train,y_test = train_test_split(df['text_clean'], 
                                                  df['target'], random_state = 42, test_size = 0.2)

# %%
Xtrain_encoded = regular_encode(X_train.to_list(), tokenizer, maxlen=300)
ytrain_encoded = tf.keras.utils.to_categorical(y_train, num_classes=16,dtype = 'int32')
Xtest_encoded = regular_encode(X_test.to_list(), tokenizer, maxlen=300)
ytest_encoded = tf.keras.utils.to_categorical(y_test, num_classes=16,dtype = 'int32')

# %%
def build_model(transformer, loss='categorical_crossentropy', max_len=512):
    input_word_ids = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name="input_word_ids")
    sequence_output = transformer(input_word_ids)[0]
    cls_token = sequence_output[:, 0, :]
    #adding dropout layer
    x = tf.keras.layers.Dropout(0.3)(cls_token)
    #using a dense layer of 16 neurons as the number of unique categories is 16. 
    out = tf.keras.layers.Dense(16, activation='softmax')(x)
    model = tf.keras.Model(inputs=input_word_ids, outputs=out)
    #using categorical crossentropy as the loss as it is a multi-class classification problem
    model.compile(tf.keras.optimizers.Adam(learning_rate=1e-04,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-08), loss=loss, metrics=['accuracy'])
    return model

# %%
#building the model on tpu
with strategy.scope():
    transformer_layer = transformers.TFAutoModel.from_pretrained('google/electra-small-discriminator')
    model = build_model(transformer_layer, max_len=300)
model.summary()
# Out:
# Some layers from the model checkpoint at google/electra-small-discriminator were not used when initializing TFElectraModel: ['discriminator_predictions']
# - This IS expected if you are initializing TFElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFElectraModel were initialized from the model checkpoint at google/electra-small-discriminator.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFElectraModel for predictions without further training.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_word_ids (InputLayer)  [(None, 300)]            0
#
#  tf_electra_model (TFElectra  TFBaseModelOutputWithPas  13483008
#  Model)                      tAndCrossAttentions(last
#                              _hidden_state=(None, 300
#                              , 256),
#                               past_key_values=None, h
#                              idden_states=None, atten
#                              tions=None, cross_attent
#                              ions=None)
#
#  tf.__operators__.getitem (S  (None, 256)              0
#  licingOpLambda)
#
#  dropout_37 (Dropout)        (None, 256)               0
#
#  dense (Dense)               (None, 16)                4112
#
# =================================================================
# Total params: 13,487,120
# Trainable params: 13,487,120
# Non-trainable params: 0
# _________________________________________________________________

# %%
#creating the training and testing dataset.
BATCH_SIZE = 16*strategy.num_replicas_in_sync
AUTO = tf.data.experimental.AUTOTUNE 
train_dataset = (
    tf.data.Dataset
    .from_tensor_slices((Xtrain_encoded, ytrain_encoded))
    .repeat()
    .shuffle(512)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)
test_dataset = (
    tf.data.Dataset
    .from_tensor_slices(Xtest_encoded)
    .batch(BATCH_SIZE)
)

# %%
import os

# %%
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "training_1/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq=5*BATCH_SIZE)

# %%
# Save the weights using the `checkpoint_path` format
model.save_weights(checkpoint_path.format(epoch=0))

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=1)

# %%
#training for 2 epochs
n_steps = Xtrain_encoded.shape[0] // BATCH_SIZE
train_history = model.fit(
    train_dataset,
    steps_per_epoch=n_steps,
    epochs=2,callbacks=[[cp_callback,early_stop]]
)
# Out:
# Epoch 1/2
#  79/881 [=>............................] - ETA: 1:00:12 - loss: 2.9448 - accuracy: 0.1218
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 159/881 [====>.........................] - ETA: 53:56 - loss: 2.7818 - accuracy: 0.1513
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 239/881 [=======>......................] - ETA: 47:15 - loss: 2.4303 - accuracy: 0.2586
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 319/881 [=========>....................] - ETA: 40:41 - loss: 2.1582 - accuracy: 0.3517
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 399/881 [============>.................] - ETA: 34:27 - loss: 1.9626 - accuracy: 0.4131
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 479/881 [===============>..............] - ETA: 28:29 - loss: 1.8191 - accuracy: 0.4582
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 559/881 [==================>...........] - ETA: 22:44 - loss: 1.6897 - accuracy: 0.5022
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 639/881 [====================>.........] - ETA: 17:00 - loss: 1.5874 - accuracy: 0.5349
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 719/881 [=======================>......] - ETA: 11:22 - loss: 1.5005 - accuracy: 0.5615
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 799/881 [==========================>...] - ETA: 5:44 - loss: 1.4237 - accuracy: 0.5845
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 879/881 [============================>.] - ETA: 8s - loss: 1.3612 - accuracy: 0.6032
# Epoch 1: saving model to training_1\cp-0001.ckpt
# 881/881 [==============================] - 3720s 4s/step - loss: 1.3597 - accuracy: 0.6038
# Epoch 2/2
#  78/881 [=>............................] - ETA: 54:57 - loss: 0.7350 - accuracy: 0.8069
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 158/881 [====>.........................] - ETA: 49:31 - loss: 0.6764 - accuracy: 0.8180
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 238/881 [=======>......................] - ETA: 44:06 - loss: 0.6622 - accuracy: 0.8204
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 318/881 [=========>....................] - ETA: 38:37 - loss: 0.6350 - accuracy: 0.8286
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 398/881 [============>.................] - ETA: 33:09 - loss: 0.6330 - accuracy: 0.8287
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 478/881 [===============>..............] - ETA: 27:39 - loss: 0.6205 - accuracy: 0.8302
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 558/881 [==================>...........] - ETA: 22:10 - loss: 0.6044 - accuracy: 0.8349
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 638/881 [====================>.........] - ETA: 16:40 - loss: 0.5941 - accuracy: 0.8374
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 718/881 [=======================>......] - ETA: 11:11 - loss: 0.5871 - accuracy: 0.8384
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 798/881 [==========================>...] - ETA: 5:41 - loss: 0.5788 - accuracy: 0.8404
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 878/881 [============================>.] - ETA: 12s - loss: 0.5721 - accuracy: 0.8420
# Epoch 2: saving model to training_1\cp-0002.ckpt
# 881/881 [==============================] - 3630s 4s/step - loss: 0.5716 - accuracy: 0.8422

# %%
from tensorflow import keras
path = './electra_model.h5'

# %%
# Calling `save('my_model.h5')` creates a h5 file `my_model.h5`.
model.save(path)

# %%
# It can be used to reconstruct the model identically.
reconstructed_model = keras.models.load_model(path,  custom_objects={"TFElectraModel":  TFElectraModel})

# %%
preds = reconstructed_model.predict(test_dataset)
# Out:
# 221/221 [==============================] - 266s 1s/step

# %%
pred_classes = np.argmax(preds, axis = 1)
pred_classes
# Out:
# array([ 3,  7, 11, ..., 11,  1,  7], dtype=int64)

# %%
result_df = pd.DataFrame({'description':X_test,'true_category':y_test, 'predicted_category':pred_classes})
result_df.head()
# Out:
#                                              description  true_category  \
# 7168   there are several programmes and initiatives w...              3
# 5464   these conventional plants run less frequently ...              7
# 5809   a betterdesigned approach could help win suppo...             11
# 16100  wind production capacity and demand profiles a...              7
# 14950  in kamali however the early warning system wor...             13
#
#        predicted_category
# 7168                    3
# 5464                    7
# 5809                   11
# 16100                   7
# 14950                  11

# %%
print(f"Accuracy is {sklearn.metrics.accuracy_score(result_df['true_category'], result_df['predicted_category'])}")
# Out:
# Accuracy is 0.8488800680464984

# %%
print(f"Precision is {sklearn.metrics.precision_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# Precision is 0.8656186128722333

# %%
print(f"Recall is {sklearn.metrics.recall_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# Recall is 0.8488800680464984

# %%
print(f"F1 Score is {sklearn.metrics.f1_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# F1 Score is 0.8526067472857626

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(result_df['true_category'], result_df['predicted_category'])
ConfusionMatrixDisplay(cm).plot()

# %%
from sklearn.preprocessing import label_binarize

# %%
y_test = label_binarize(result_df['true_category'],classes=np.unique(result_df['true_category']))
y_pred = preds[:,1:]

# %%
from sklearn.metrics import roc_curve, auc

# Learn to predict each class against the other


n_classes = 15 # number of class
plt.figure(figsize=(8,8),dpi=200)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i], )
    roc_auc[i] = auc(fpr[i], tpr[i])    
    
    lw = 2 # line_width
    plt.plot(fpr[i], tpr[i], linestyle='--',
    lw=lw, label='%s vs Rest (AUC = %0.2f)' % (i+1,roc_auc[i])) # Drawing Curve according to 15. class 
    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
test_df = pd.read_excel("test_dataset_updated.xlsx")

# %%
test_df.head()
# Out:
#                                         News Summary  \
# 0   agricultural engineer eduardo assad has devot...
# 1   agricultural organizations are joining forces...
# 2   aim4c coalition pledged to accelerate innovat...
# 3   alaa abd el fattah one of egypts most high pr...
# 4   alcazar energy partners ii slp scsp aep ii br...
#
#                           OSDG  OSDG Label
# 0               Climate Action          13
# 1                  Zero Hunger           2
# 2               Climate Action          13
# 3               Climate Action          13
# 4  Affordable and Clean Energy           7

# %%
news = test_df['News Summary']

# %%
labels = test_df['OSDG Label']

# %%
def encode_news(new, tokenizer):
    news_encoded = regular_encode(new.tolist(), tokenizer, maxlen=300)
    news_dataset = (tf.data.Dataset.from_tensor_slices(news_encoded).batch(BATCH_SIZE))
    return news_dataset

# %%
news_prepared = encode_news(news,tokenizer)

# %%
pred_class = reconstructed_model.predict(news_prepared)
# Out:
# 111/111 [==============================] - 135s 1s/step

# %%
pred_classes = np.argmax(pred_class, axis = 1)
pred_classes
# Out:
# array([13,  2,  2, ..., 13, 13,  2], dtype=int64)

# %%
result_df = pd.DataFrame({'news':test_df['News Summary'],'true_category':test_df['OSDG Label'], 'predicted_category':pred_classes})
result_df
# Out:
#                                                    news  true_category  \
# 0      agricultural engineer eduardo assad has devot...             13
# 1      agricultural organizations are joining forces...              2
# 2      aim4c coalition pledged to accelerate innovat...             13
# 3      alaa abd el fattah one of egypts most high pr...             13
# 4      alcazar energy partners ii slp scsp aep ii br...              7
# ...                                                 ...            ...
# 1770  Young activists from outside the country espec...             13
# 1771  Youth climate activism is bearing fruit our an...             13
# 1772  Youth climate activist greta thunberg has a bo...             13
# 1773  Zambia's environment minister collins nzovu de...             13
# 1774  Zimbabwean security guard edwin dapi was alrea...              2
#
#       predicted_category
# 0                     13
# 1                      2
# 2                      2
# 3                     13
# 4                      7
# ...                  ...
# 1770                  13
# 1771                  13
# 1772                  13
# 1773                  13
# 1774                   2
#
# [1775 rows x 3 columns]

# %%
print(f"Accuracy is {sklearn.metrics.accuracy_score(result_df['true_category'], result_df['predicted_category'])}")
# Out:
# Accuracy is 0.6715492957746478

# %%
print(f"Recall is {sklearn.metrics.recall_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# Recall is 0.6715492957746478

# %%
print(f"Precision is {sklearn.metrics.precision_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# Precision is 0.8313739193898093

# %%
print(f"F1 Score is {sklearn.metrics.f1_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# F1 Score is 0.7022226302391775

# %%
cm = confusion_matrix(result_df['true_category'], result_df['predicted_category'])
ConfusionMatrixDisplay(cm).plot()

# %%
# Learn to predict each class against the other
y_test = label_binarize(result_df['true_category'],classes=np.unique(result_df['true_category']))
y_pred = pred_class[:,1:]

n_classes = 15 # number of class
plt.figure(figsize=(8,8),dpi=200)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i], )
    roc_auc[i] = auc(fpr[i], tpr[i])    
    
    lw = 2 # line_width
    plt.plot(fpr[i], tpr[i], linestyle='--',
    lw=lw, label='%s vs Rest (AUC = %0.2f)' % (i+1,roc_auc[i])) # Drawing Curve according to 15. class 
    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
 # saving the excel
file_name = 'electra_results.xlsx'
result_df.to_excel(file_name)
