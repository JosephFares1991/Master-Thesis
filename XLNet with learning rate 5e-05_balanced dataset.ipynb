# %%
# https://github.com/Shivampanwar/Bert-text-classification/blob/master/XLNet/xlnet_experimentation.ipynb

# %%
pip install pytorch-transformers
# Out:
# Requirement already satisfied: pytorch-transformers in c:\users\joseph fares\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: sacremoses in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (0.0.53)
# Requirement already satisfied: torch>=1.0.0 in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (1.12.1)
# Requirement already satisfied: numpy in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (1.23.5)
# Requirement already satisfied: sentencepiece in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (0.1.99)
# Requirement already satisfied: tqdm in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (4.64.1)
# Requirement already satisfied: regex in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (2022.7.9)
# Requirement already satisfied: boto3 in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (1.26.155)
# Requirement already satisfied: requests in c:\users\joseph fares\anaconda3\lib\site-packages (from pytorch-transformers) (2.28.1)
# Requirement already satisfied: typing_extensions in c:\users\joseph fares\anaconda3\lib\site-packages (from torch>=1.0.0->pytorch-transformers) (4.4.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\joseph fares\anaconda3\lib\site-packages (from boto3->pytorch-transformers) (0.10.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.155 in c:\users\joseph fares\anaconda3\lib\site-packages (from boto3->pytorch-transformers) (1.29.155)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\joseph fares\anaconda3\lib\site-packages (from boto3->pytorch-transformers) (0.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joseph fares\anaconda3\lib\site-packages (from requests->pytorch-transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\joseph fares\anaconda3\lib\site-packages (from requests->pytorch-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joseph fares\anaconda3\lib\site-packages (from requests->pytorch-transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joseph fares\anaconda3\lib\site-packages (from requests->pytorch-transformers) (1.26.14)
# Requirement already satisfied: click in c:\users\joseph fares\anaconda3\lib\site-packages (from sacremoses->pytorch-transformers) (8.0.4)
# Requirement already satisfied: six in c:\users\joseph fares\anaconda3\lib\site-packages (from sacremoses->pytorch-transformers) (1.16.0)
# Requirement already satisfied: joblib in c:\users\joseph fares\anaconda3\lib\site-packages (from sacremoses->pytorch-transformers) (1.1.1)
# Requirement already satisfied: colorama in c:\users\joseph fares\anaconda3\lib\site-packages (from tqdm->pytorch-transformers) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\joseph fares\anaconda3\lib\site-packages (from botocore<1.30.0,>=1.29.155->boto3->pytorch-transformers) (2.8.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras_preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split


from transformers import XLNetModel, XLNetTokenizer, XLNetForSequenceClassification
from pytorch_transformers import AdamW

from tqdm import tqdm, trange
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
from __future__ import print_function
import ipywidgets as widgets
import re
from sklearn.preprocessing import LabelEncoder

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
df = pd.read_csv("data_transformer.csv")

# %%
df.head()
# Out:
#                                           text_clean  target
# 0  from a gender perspective paulgaard points out...       5
# 1  the average figure also masks large difference...       3
# 2  the israel oceanographic and limnological rese...       6
# 3  previous chapters have discussed ways to make ...       2
# 4  prescription rates appear to be higher where l...       8

# %%
sentences = df['text_clean'].values

# %%
# Simple cleaning of text ahead of summarisation

def clean_text(text):
    text = text.encode("ascii", errors="ignore").decode("ascii") #remove non-ascii, Chinese characters
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"\n", " ", text)
    text = re.sub(r"\n\n", " ", text)
    text = re.sub(r"\W", " ", text)
    text = re.sub(r"^\d+\s|\s\d+\s|\s\d+$", " ", text)
    text = text.strip(" ")
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(' +',' ', text).strip() # get rid of multiple spaces and replace with a single
    return text

# %%
df["text_clean"] = df["text_clean"].apply(lambda text:clean_text(str(text)))

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='target',data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
X_train,X_test ,y_train,y_test = train_test_split(df['text_clean'], 
                                                  df['target'], random_state = 42, test_size = 0.2)

# %%
from transformers import TFXLNetModel, XLNetTokenizer
xlnet_model = 'xlnet-base-cased'
xlnet_tokenizer = XLNetTokenizer.from_pretrained(xlnet_model)

# %%
def regular_encode(texts, tokenizer, maxlen=512):
    enc_di = tokenizer.batch_encode_plus(
        texts,         
        return_token_type_ids=False,
        padding='max_length',
        max_length=maxlen, 
        truncation=True
    )
    
    return np.array(enc_di['input_ids'])

# %%
Xtrain_encoded = regular_encode(X_train.astype('str'), xlnet_tokenizer, maxlen=300)
ytrain_encoded = tf.keras.utils.to_categorical(y_train, num_classes=16,dtype = 'int32')
Xtest_encoded = regular_encode(X_test.astype('str'), xlnet_tokenizer, maxlen=300)
ytest_encoded = tf.keras.utils.to_categorical(y_test, num_classes=16,dtype = 'int32')

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
oversample = RandomOverSampler(sampling_strategy='minority')

# %%
Xtrain_encoded,ytrain_encoded = oversample.fit_resample(Xtrain_encoded,ytrain_encoded)

# %%
Xtest_encoded,ytest_encoded = oversample.fit_resample(Xtest_encoded,ytest_encoded)

# %%
def create_model_xlnet(xlnet_model):
    word_inputs = tf.keras.Input(shape=(300,), name='word_inputs', dtype='int32')

    
    xlnet = TFXLNetModel.from_pretrained(xlnet_model)
    xlnet_encodings = xlnet(word_inputs)[0]

    # Collect last step from last hidden state (CLS)
    doc_encoding = tf.squeeze(xlnet_encodings[:, -1:, :], axis=1)
    
    doc_encoding = tf.keras.layers.Dropout(.1)(doc_encoding)
     
    outputs = tf.keras.layers.Dense(15, activation='softmax', name='outputs')(doc_encoding)

    model = tf.keras.Model(inputs=[word_inputs], outputs=[outputs])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-05,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
xlnet = create_model_xlnet(xlnet_model)
xlnet.summary()
# Out:
# Some layers from the model checkpoint at xlnet-base-cased were not used when initializing TFXLNetModel: ['lm_loss']
# - This IS expected if you are initializing TFXLNetModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFXLNetModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFXLNetModel were initialized from the model checkpoint at xlnet-base-cased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFXLNetModel for predictions without further training.
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  word_inputs (InputLayer)    [(None, 300)]             0
#
#  tfxl_net_model_3 (TFXLNetMo  TFXLNetModelOutput(last_  116718336
#  del)                        hidden_state=(None, 300,
#                               768),
#                               mems=((300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768),
#                               (300, None, 768)),
#                               hidden_states=None, att
#                              entions=None)
#
#  tf.__operators__.getitem_3   (None, 1, 768)           0
#  (SlicingOpLambda)
#
#  tf.compat.v1.squeeze_3 (TFO  (None, 768)              0
#  pLambda)
#
#  dropout_151 (Dropout)       (None, 768)               0
#
#  outputs (Dense)             (None, 15)                11535
#
# =================================================================
# Total params: 116,729,871
# Trainable params: 116,729,871
# Non-trainable params: 0
# _________________________________________________________________

# %%
#creating the training and testing dataset.
BATCH_SIZE = 16
AUTO = tf.data.experimental.AUTOTUNE 
train_dataset = (
    tf.data.Dataset
    .from_tensor_slices((Xtrain_encoded, ytrain_encoded))
    .repeat()
    .shuffle(512)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)
test_dataset = (
    tf.data.Dataset
    .from_tensor_slices(Xtest_encoded)
    .batch(BATCH_SIZE)
)

# %%
#training for 2 epochs
n_steps = Xtrain_encoded.shape[0] // BATCH_SIZE
train_history = xlnet.fit(
    train_dataset,
    steps_per_epoch=n_steps,
    epochs=2
)
# Out:
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['tfxl_net_model_3/transformer/mask_emb:0', 'tfxl_net_model_3/transformer/layer_._0/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._0/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._1/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._1/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._2/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._2/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._3/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._3/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._4/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._4/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._5/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._5/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._6/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._6/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._7/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._7/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._8/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._8/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._9/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._9/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._10/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._10/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._11/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._11/rel_attn/seg_embed:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tfxl_net_model_3/transformer/mask_emb:0', 'tfxl_net_model_3/transformer/layer_._0/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._0/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._1/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._1/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._2/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._2/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._3/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._3/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._4/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._4/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._5/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._5/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._6/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._6/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._7/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._7/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._8/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._8/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._9/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._9/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._10/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._10/rel_attn/seg_embed:0', 'tfxl_net_model_3/transformer/layer_._11/rel_attn/r_s_bias:0', 'tfxl_net_model_3/transformer/layer_._11/rel_attn/seg_embed:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 987/987 [==============================] - 23734s 24s/step - loss: 0.6787 - accuracy: 0.8112
# Epoch 2/2
# 987/987 [==============================] - 23826s 24s/step - loss: 0.3094 - accuracy: 0.9098

# %%
import transformers

# %%
from tensorflow import keras

# %%
# Calling `save('my_model.h5')` creates a h5 file `my_model.h5`.
xlnet.save("xlnet_model.h5")
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
# It can be used to reconstruct the model identically.
reconstructed_model = keras.models.load_model("xlnet_model.h5",  custom_objects={"TFXLNetModel": transformers.TFXLNetModel})
# Out:
# C:\Users\Joseph Fares\AppData\Roaming\Python\Python310\site-packages\keras\initializers\initializers.py:120: UserWarning: The initializer TruncatedNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
preds = reconstructed_model.predict(test_dataset)
# Out:
# 249/249 [==============================] - 2262s 9s/step

# %%
pred_classes = np.argmax(preds, axis = 1)
pred_classes
# Out:
# array([ 2,  6, 10, ..., 11, 12,  6], dtype=int64)

# %%
test_classes = np.argmax(ytest_encoded, axis = 1)
test_classes
# Out:
# array([ 2,  6, 10, ..., 11, 11, 11], dtype=int64)

# %%
import sklearn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
print(f"Accuracy is {sklearn.metrics.accuracy_score(test_classes, pred_classes)}")
# Out:
# Accuracy is 0.8799598191863385

# %%
print(f"Precision is {sklearn.metrics.precision_score(test_classes, pred_classes,average= 'weighted')}")
# Out:
# Precision is 0.8832080910437321

# %%
print(f"Recall is {sklearn.metrics.recall_score(test_classes, pred_classes,average= 'weighted')}")
# Out:
# Recall is 0.8799598191863385

# %%
print(f"F1 Score is {sklearn.metrics.f1_score(test_classes, pred_classes,average= 'weighted')}")
# Out:
# F1 Score is 0.8781340308252419

# %%
cm = confusion_matrix(test_classes, pred_classes)
ConfusionMatrixDisplay(cm).plot()

# %%
from sklearn.preprocessing import label_binarize

# %%
y_test = label_binarize(test_classes,classes=np.unique(test_classes))
y_pred = preds

# %%
from sklearn.metrics import roc_curve, auc

# Learn to predict each class against the other


n_classes = 15 # number of class
plt.figure(figsize=(8,8),dpi=200)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i], )
    roc_auc[i] = auc(fpr[i], tpr[i])    
    
    lw = 2 # line_width
    plt.plot(fpr[i], tpr[i], linestyle='--',
    lw=lw, label='%s vs Rest (AUC = %0.2f)' % (i+1,roc_auc[i])) # Drawing Curve according to 15. class 
    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
test_df = pd.read_excel("test_dataset_updated.xlsx")

# %%
test_df.head()
# Out:
#                                         News Summary  \
# 0   agricultural engineer eduardo assad has devot...
# 1   agricultural organizations are joining forces...
# 2   aim4c coalition pledged to accelerate innovat...
# 3   alaa abd el fattah one of egypts most high pr...
# 4   alcazar energy partners ii slp scsp aep ii br...
#
#                           OSDG  OSDG Label
# 0               Climate Action          13
# 1                  Zero Hunger           2
# 2               Climate Action          13
# 3               Climate Action          13
# 4  Affordable and Clean Energy           7

# %%
news = test_df['News Summary']
labels = test_df['OSDG Label']

# %%
def encode_news(new, tokenizer):
    news_encoded = regular_encode(new.astype('str'), tokenizer, maxlen=300)
    news_dataset = (tf.data.Dataset.from_tensor_slices(news_encoded).batch(BATCH_SIZE))
    return news_dataset

# %%
news_prepared = encode_news(news,xlnet_tokenizer)

# %%
pred_class = reconstructed_model.predict(news_prepared)
# Out:
# 111/111 [==============================] - 990s 9s/step

# %%
pred_classes = np.argmax(pred_class, axis = 1)+1
pred_classes
# Out:
# array([13,  2, 13, ..., 13, 13,  2], dtype=int64)

# %%
result_df = pd.DataFrame({'news':test_df['News Summary'],'true_category':test_df['OSDG Label'], 'predicted_category':pred_classes})
result_df
# Out:
#                                                    news  true_category  \
# 0      agricultural engineer eduardo assad has devot...             13
# 1      agricultural organizations are joining forces...              2
# 2      aim4c coalition pledged to accelerate innovat...             13
# 3      alaa abd el fattah one of egypts most high pr...             13
# 4      alcazar energy partners ii slp scsp aep ii br...              7
# ...                                                 ...            ...
# 1770  Young activists from outside the country espec...             13
# 1771  Youth climate activism is bearing fruit our an...             13
# 1772  Youth climate activist greta thunberg has a bo...             13
# 1773  Zambia's environment minister collins nzovu de...             13
# 1774  Zimbabwean security guard edwin dapi was alrea...              2
#
#       predicted_category
# 0                     13
# 1                      2
# 2                     13
# 3                     13
# 4                      7
# ...                  ...
# 1770                  13
# 1771                  13
# 1772                  13
# 1773                  13
# 1774                   2
#
# [1775 rows x 3 columns]

# %%
print(f"Accuracy is {sklearn.metrics.accuracy_score(result_df['true_category'], result_df['predicted_category'])}")
# Out:
# Accuracy is 0.8574647887323944

# %%
print(f"Precision is {sklearn.metrics.precision_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# Precision is 0.8756249924891175
# C:\Users\Joseph Fares\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(f"Recall is {sklearn.metrics.recall_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# Recall is 0.8574647887323944

# %%
print(f"F1-Score is {sklearn.metrics.f1_score(result_df['true_category'], result_df['predicted_category'],average= 'weighted')}")
# Out:
# F1-Score is 0.8610090747423333

# %%
cm = confusion_matrix(result_df['true_category'], result_df['predicted_category'])
ConfusionMatrixDisplay(cm).plot()

# %%
# Learn to predict each class against the other
y_test = label_binarize(result_df['true_category'],classes=np.unique(result_df['true_category']))
y_pred = pred_class

n_classes = 15 # number of class
plt.figure(figsize=(8,8),dpi=200)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i], )
    roc_auc[i] = auc(fpr[i], tpr[i])    
    
    lw = 2 # line_width
    plt.plot(fpr[i], tpr[i], linestyle='--',
    lw=lw, label='%s vs Rest (AUC = %0.2f)' % (i+1,roc_auc[i])) # Drawing Curve according to 15. class 
    
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
 # saving the excel
file_name = 'xlnet_results.xlsx'
result_df.to_excel(file_name)
